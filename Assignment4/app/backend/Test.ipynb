# %%
from sqlalchemy import create_engine, text

urls = [
    "mysql+mysqlconnector://QueryWorks:password%40123@10.0.116.184:3307/QueryWorks?ssl_disabled=True",
    "mysql+mysqlconnector://QueryWorks:password%40123@10.0.116.184:3308/QueryWorks?ssl_disabled=True",
    "mysql+mysqlconnector://QueryWorks:password%40123@10.0.116.184:3309/QueryWorks?ssl_disabled=True"
]

for i, url in enumerate(urls):
    print(f"\n===== SHARD {i} =====")
    engine = create_engine(url)

    with engine.connect() as conn:
        # Members
        print("\n--- Members (top 5) ---")
        res = conn.execute(text("SELECT * FROM Members LIMIT 5"))
        for row in res:
            print(row)

        # ActiveRides
        print("\n--- ActiveRides (top 5) ---")
        res = conn.execute(text("SELECT * FROM ActiveRides LIMIT 5"))
        for row in res:
            print(row)
# Out:
# ===== SHARD 0 =====
#
# --- Members (top 5) ---
# (28498438, 'dummy_sub_28498438', 'Myra Khan', 'https://robohash.org/28498438.png?set=set4', 'M.Tech.', 'Computer Science and Engineering', 2029, 'myra.khan@iitgn.ac.in', '6371872528', 22, 'F')
# (28498440, 'dummy_sub_28498440', 'Ayaan Nair', 'https://robohash.org/28498440.png?set=set4', 'PhD', 'Artificial Intelligence', 2026, 'ayaan.nair@iitgn.ac.in', '9965758745', 29, 'M')
# (28498442, 'dummy_sub_28498442', 'Arjun Mishra', 'https://robohash.org/28498442.png?set=set4', 'B.Tech.', 'Computer Science and Engineering', 2029, 'arjun.mishra@iitgn.ac.in', '9036360323', 23, 'M')
# (28498446, 'dummy_sub_28498446', 'Ishaan Chaudhary', 'https://robohash.org/28498446.png?set=set4', 'B.Tech.', 'Computer Science and Engineering', 2026, 'ishaan.chaudhary@iitgn.ac.in', '8938941125', 18, 'M')
# ...
